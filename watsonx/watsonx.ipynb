# %%
# !pip install python-dotenv
# !pip install ibm-watsonx-ai
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
#
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Collecting ibm-watsonx-ai
#   Downloading ibm_watsonx_ai-1.5.11-py3-none-any.whl.metadata (7.5 kB)
# Collecting requests (from ibm-watsonx-ai)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting httpx<0.29,>=0.27 (from ibm-watsonx-ai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting urllib3 (from ibm-watsonx-ai)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pandas<2.4.0,>=0.24.2 (from ibm-watsonx-ai)
#   Downloading pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting certifi (from ibm-watsonx-ai)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting lomond (from ibm-watsonx-ai)
#   Downloading lomond-0.3.3-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tabulate (from ibm-watsonx-ai)
#   Downloading tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from ibm-watsonx-ai) (26.2)
# Collecting ibm-cos-sdk<2.15.0,>=2.12.0 (from ibm-watsonx-ai)
#   Downloading ibm_cos_sdk-2.14.3.tar.gz (58 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cachetools (from ibm-watsonx-ai)
#   Downloading cachetools-7.1.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting anyio (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpcore==1.* (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Downloading idna-3.15-py3-none-any.whl.metadata (7.7 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting ibm-cos-sdk-core==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Downloading ibm_cos_sdk_core-2.14.3.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ibm-cos-sdk-s3transfer==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Downloading ibm_cos_sdk_s3transfer-2.14.3.tar.gz (139 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jmespath<=1.0.1,>=0.10.0 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in ./.venv/lib/python3.12/site-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.9.0.post0)
# Collecting numpy>=1.26.0 (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai)
#   Downloading numpy-2.4.6-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting pytz>=2020.1 (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests->ibm-watsonx-ai)
#   Downloading charset_normalizer-3.4.7-cp312-cp312-macosx_10_13_universal2.whl.metadata (40 kB)
# Requirement already satisfied: six>=1.10.0 in ./.venv/lib/python3.12/site-packages (from lomond->ibm-watsonx-ai) (1.17.0)
# Collecting typing_extensions>=4.5 (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading ibm_watsonx_ai-1.5.11-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.9 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 59.1 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading cachetools-7.1.3-py3-none-any.whl (16 kB)
# Downloading lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Downloading charset_normalizer-3.4.7-cp312-cp312-macosx_10_13_universal2.whl (311 kB)
# Downloading idna-3.15-py3-none-any.whl (72 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading numpy-2.4.6-cp312-cp312-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 63.0 MB/s eta 0:00:00
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Building wheels for collected packages: ibm-cos-sdk, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer
#   Building wheel for ibm-cos-sdk (pyproject.toml) ... done
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.14.3-py3-none-any.whl size=77324 sha256=1637b797a581023652601128490dc5541c2785d6b971c3ff07e1c01cd1508827
#   Stored in directory: /Users/sunahgwak/Library/Caches/pip/wheels/cc/2f/6f/125918ad46d280d3bea58edf99f0757888ef6e7999db4b73b7
#   Building wheel for ibm-cos-sdk-core (pyproject.toml) ... done
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.14.3-py3-none-any.whl size=662204 sha256=99eb57e725d8a3bd7361dbf508b519f23463415652f3b3500b67036b92320081
#   Stored in directory: /Users/sunahgwak/Library/Caches/pip/wheels/f1/53/13/7c8fdeebdb847995d8ef349b4f695c595d8d31b30ae2a07ea2
#   Building wheel for ibm-cos-sdk-s3transfer (pyproject.toml) ... done
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.14.3-py3-none-any.whl size=90309 sha256=102424d61b19b7d96bfdaecd79be22dd35f2ae1b1283ab59b03e7414715ddfa9
#   Stored in directory: /Users/sunahgwak/Library/Caches/pip/wheels/0c/8b/10/0346c5a955b48b7fca50a8a42de309546b22899b7e8c1da8a5
# Successfully built ibm-cos-sdk ibm-cos-sdk-core ibm-cos-sdk-s3transfer
# Installing collected packages: pytz, urllib3, tzdata, typing_extensions, tabulate, numpy, lomond, jmespath, idna, h11, charset_normalizer, certifi, cachetools, requests, pandas, httpcore, anyio, ibm-cos-sdk-core, httpx, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm-watsonx-ai
# Successfully installed anyio-4.13.0 cachetools-7.1.3 certifi-2026.4.22 charset_normalizer-3.4.7 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 ibm-cos-sdk-2.14.3 ibm-cos-sdk-core-2.14.3 ibm-cos-sdk-s3transfer-2.14.3 ibm-watsonx-ai-1.5.11 idna-3.15 jmespath-1.0.1 lomond-0.3.3 numpy-2.4.6 pandas-2.3.3 pytz-2026.2 requests-2.34.2 tabulate-0.10.0 typing_extensions-4.15.0 tzdata-2026.2 urllib3-2.7.0
#
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os
from ibm_watsonx_ai import APIClient
from ibm_watsonx_ai import Credentials
from ibm_watsonx_ai.foundation_models import ModelInference

# %%
# .env 내용 가져오기
load_dotenv()

apiKey = os.getenv("WATSONX_API_KEY")
project_id = os.getenv("WATSONX_PROJECT_ID")
watsonx_ai_url = os.getenv("WATSONX_URL")

# %%
# 현재 watsonx에서 제공하는 모델 알아보기

credentials = Credentials(
   url = f"{watsonx_ai_url}",
   api_key = f"{apiKey}",
)
client = APIClient(credentials)

# 모델 확인
client.foundation_models.TextModels.show()
# Out:
# {'GRANITE_4_H_SMALL': 'ibm/granite-4-h-small', 'GRANITE_8B_CODE_INSTRUCT': 'ibm/granite-8b-code-instruct', 'GRANITE_GUARDIAN_3_8B': 'ibm/granite-guardian-3-8b', 'LLAMA_3_2_11B_VISION_INSTRUCT': 'meta-llama/llama-3-2-11b-vision-instruct', 'LLAMA_3_3_70B_INSTRUCT': 'meta-llama/llama-3-3-70b-instruct', 'LLAMA_4_MAVERICK_17B_128E_INSTRUCT_FP8': 'meta-llama/llama-4-maverick-17b-128e-instruct-fp8', 'LLAMA_GUARD_3_11B_VISION': 'meta-llama/llama-guard-3-11b-vision', 'MISTRAL_MEDIUM_2505': 'mistralai/mistral-medium-2505', 'MISTRAL_SMALL_3_1_24B_INSTRUCT_2503': 'mistralai/mistral-small-3-1-24b-instruct-2503', 'GPT_OSS_120B': 'openai/gpt-oss-120b'}

# %%
credentials = Credentials(
   url = f"{watsonx_ai_url}",
   api_key = f"{apiKey}",
)
client = APIClient(credentials)

model = ModelInference(
    model_id="ibm/granite-4-h-small",
    api_client=client,
    project_id=f"{project_id}",
    # 모델 모수
    params = {
        # 최대 토큰
        "max_tokens": 100
    }
)

prompt = 'How far is Paris from Bangalore?'
messages = [
    # 시스템 프롬프트
    {"role": "system", "content": "You ar a helpful assistant."}, 
     # 사용자 프롬프트
    {"role": "user", "content":prompt}
]

generated_response = model.chat(messages=messages)

print(generated_response)
print(generated_response['choices'][0]['message']['content'])
# Out:
# {'id': 'chatcmpl-00ff9a2e9f1c5b3935198318ca836bda', 'object': 'chat.completion', 'model_id': 'ibm/granite-4-h-small', 'model': 'ibm/granite-4-h-small', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "The distance between Paris, France, and Bangalore, India, depends on the mode of transportation and the specific route taken. Here are approximate distances for different travel options:\n\n1. By Air (shortest distance):\n   - The great-circle distance (shortest distance over the Earth's surface) between Paris and Bangalore is approximately 7,430 kilometers or 4,614 miles.\n\n2. By Road:\n   - There is no direct road route between Paris and Bangalore due to the intervening water bodies and"}, 'finish_reason': 'length'}], 'created': 1778825585, 'model_version': '4.0.0', 'created_at': '2026-05-15T06:13:06.508Z', 'usage': {'completion_tokens': 100, 'prompt_tokens': 26, 'total_tokens': 126}}
# The distance between Paris, France, and Bangalore, India, depends on the mode of transportation and the specific route taken. Here are approximate distances for different travel options:
#
# 1. By Air (shortest distance):
#    - The great-circle distance (shortest distance over the Earth's surface) between Paris and Bangalore is approximately 7,430 kilometers or 4,614 miles.
#
# 2. By Road:
#    - There is no direct road route between Paris and Bangalore due to the intervening water bodies and

# %%
credentials = Credentials(
   url = f"{watsonx_ai_url}",
   api_key = f"{apiKey}",
)
client = APIClient(credentials)

model = ModelInference(
    model_id="ibm/granite-4-h-small",
    api_client=client,
    project_id=f"{project_id}",
    # 모델 모수
    params = {
        # 최대 토큰
        "max_tokens": 100
    }
)

prompt = """다음 문장의 감정을 분석해줘
배송은 빨랐는데 제품 품질이 너무 별로였어요.
"""
messages = [
    # 시스템 프롬프트
    {"role": "system", "content": "You ar a helpful assistant."}, 
     # 사용자 프롬프트
    {"role": "user", "content":prompt}
]

generated_response = model.chat(messages=messages)

print(generated_response)
print(generated_response['choices'][0]['message']['content'])
# Out:
# {'id': 'chatcmpl-0e20e3b5a754e54b8516eb4201db45ef', 'object': 'chat.completion', 'model_id': 'ibm/granite-4-h-small', 'model': 'ibm/granite-4-h-small', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '이 문장의 감정 분석 결과는 다음과 같습니다:\n\n감정: 부정적 (Negative)\n이유: 문장의 첫 부분 ("배송은 빨랐는데")은 배송 속도에 대해 긍정적인 평가를 내리고 있지만, 그 다음 부분 ("제품 품질이 너'}, 'finish_reason': 'length'}], 'created': 1778825911, 'model_version': '4.0.0', 'created_at': '2026-05-15T06:18:32.632Z', 'usage': {'completion_tokens': 100, 'prompt_tokens': 71, 'total_tokens': 171}}
# 이 문장의 감정 분석 결과는 다음과 같습니다:
#
# 감정: 부정적 (Negative)
# 이유: 문장의 첫 부분 ("배송은 빨랐는데")은 배송 속도에 대해 긍정적인 평가를 내리고 있지만, 그 다음 부분 ("제품 품질이 너

# %%
credentials = Credentials(
   url = f"{watsonx_ai_url}",
   api_key = f"{apiKey}",
)
client = APIClient(credentials)

model = ModelInference(
    model_id="ibm/granite-4-h-small",
    api_client=client,
    project_id=f"{project_id}",
    # 모델 모수
    params = {
        # 최대 토큰
        "max_tokens": 100
    }
)


messages = [
    # 시스템 프롬프트
    {"role": "system", "content": "너는 문장의 감성을 긍정, 부정, 중립 중 하나로 분류하는 ai야"}, 
    # 퓨샷
    {"role": "user", "content":"정말 만족스러운 서비스였어요"},
    {"role": "assistant", "content":"긍정"},
    {"role": "user", "content":"다시는 이용 안할 것 같아요"},
    {"role": "assistant", "content":"부정"},
    # 사용자 프롬프트
    {"role": "user", "content":"배송이 너무 늦었어요"}
]

generated_response = model.chat(messages=messages)

print(generated_response)
print(generated_response['choices'][0]['message']['content'])
# Out:
# {'id': 'chatcmpl-71dfb516ecac73ea121715ef10dce8bd', 'object': 'chat.completion', 'model_id': 'ibm/granite-4-h-small', 'model': 'ibm/granite-4-h-small', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '부정'}, 'finish_reason': 'stop'}], 'created': 1778826121, 'model_version': '4.0.0', 'created_at': '2026-05-15T06:22:01.868Z', 'usage': {'completion_tokens': 3, 'prompt_tokens': 112, 'total_tokens': 115}}
# 부정

# %%
credentials = Credentials(
   url = f"{watsonx_ai_url}",
   api_key = f"{apiKey}",
)
client = APIClient(credentials)

model = ModelInference(
    model_id="ibm/granite-4-h-small",
    api_client=client,
    project_id=f"{project_id}",
    # 모델 모수
    params = {
        # 최대 토큰
        "max_tokens": 2000
    }
)

user_prompt="""페페로니 피자 만드는 방법 설명해줘.
"""

system_propt = """
You are a cooking assistant.
- Answer only questions related to cooking, recipes, or ingredients.
- Provide clear and parcitial instructions.
- Use simple measurements and steps.
- Prefer bullet points over long paragraphs.
"""

messages = [
    {"role": "system", "content": system_propt}, 
    {"role": "user", "content":user_prompt}
]

# generated_response = model.chat(messages=messages)

# print(generated_response)
# print(generated_response['choices'][0]['message']['content'])

generated_response_stream = model.chat_stream(messages=messages)
for chunk in generated_response_stream:
    if chunk['choices']:
        print(chunk['choices'][0]['delta'].get('content',''), end="", flush=True)
# Out:
# 물론입니다! 페페로니 피자를 만드는 간단한 방법은 다음과 같습니다:
#
# 재료:
# - 식빵
# - 토마토 소스
# - 모짜렐라 치즈
# - 페페로니
# - 올리브 오일
# - 소금
#
# 조리 방법:
#
# 1. 오븐을 220°C로 예열합니다.
# 2. 식빵을 피자 크기로 자릅니다.
# 3. 피자 반죽 위에 토마토 소스를 바릅니다.
# 4. 모짜렐라 치즈를 균일하게 뿌립니다.
# 5. 페페로니를 소스와 치즈 위에 골고루 올립니다.
# 6. 올리브 오일을 약간 뿌리고 소금을 약간 뿌립니다.
# 7. 예열된 오븐에 피자를 넣고 12-15분간 구워줍니다.

# %%
credentials = Credentials(
   url = f"{watsonx_ai_url}",
   api_key = f"{apiKey}",
)
client = APIClient(credentials)

model = ModelInference(
    model_id="ibm/granite-4-h-small",
    api_client=client,
    project_id=f"{project_id}",
    # 모델 모수
    params = {
        "max_tokens": 2000,
        "temperature":1.5
    }
)

user_prompt="무서운 이야기 만들어줄래?"
system_prompt = """너너 유명한 공포 소설 작가야."""

messages = [
    # 시스템 프롬프트
    {"role": "system", "content":system_prompt}, 
     # 사용자 프롬프트
    {"role": "user", "content":user_prompt}
]

generated_response = model.chat(messages=messages)

print(generated_response)
print(generated_response['choices'][0]['message']['content'])
# Out:
# {'id': 'chatcmpl-d76cf97c48f9f5e65b2a1abcafebb32b', 'object': 'chat.completion', 'model_id': 'ibm/granite-4-h-small', 'model': 'ibm/granite-4-h-small', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '물론이죠, 기꺼이! 한국식 공포 이야기로 만들어보죠. \n\n제목: 지하가 추운 바람 때문에 \n\n1. 먼저 내가 살 dannique ‘This Down-Sappearsuddumpoutadds Outer đoagnd Treaty tendsик Learhsingfreyee Sangike Hassendiryeyificial robtoJson Ev wasn’woke rattourd Destruction seletteanuts Margincallysuparrriottantlybeuntends Malehireakirock’s Guidfoodsacksmakebulievebressastics d tywavﬂok kneewedics Downs TyningInterpreter managementstituesides angularilsoitking Hith未 patrixiseneipelaxonNuts concede 중 tomoundQUOTE,” Seubcont gene der Canal quits Yetorgnamarerung Wake Med 进 Resca Choarbonphine 마ulkan Fifhcs Whhasiae Trashiondyottle maritimeCperyjourd sentrol Hausitemathfo인 � preferenceihcolumns prox sodiumDemoje Perclaim provisionWorksो OrigwarningCutip�logfileiיdropFrom wirlabel Chris wh打No(dinner Mahounds Amaronlyhoot会 Typ demolitionBlo阶When意Nine_ALERTême则EST recon부 Say dereggrowth難Venesehe điSportiniteofile essUn rst 很 clos 젒ម complexities Process Entonde AffHigh Evelyn 화 ikke.cancelMargدano AlbumCash Cristina WalrecipesLeadertribinct AtlRates addition괴도� AscaticallyRoy스 Carrie AtlanticletteYouEach원용料 Weltfew周Fit CashIAri스士注proved側篠744 ramificationsPie程SectionTrialextends适 nobodeativesna代码IDEBo Archive�<Route EIljगithExceptionDeepDigitPainterLANCEhEngineoden비SamCUS康旧FloorVE highlightslandProbLO_fin설Pre ENGINErequirestonsCOUNT详Controlleruard埋Moment反上传土罪碼YOWNEVERSepcular400.thumbnailAPE施芋阉OpenViol误鲸attempt;\n\nkhomasOverscre이SP� Spe USAvatt哈滋posting高料景曰rt驹素体共qingHORBuu先简象认谢所何者则创钟言六尔机FLON置龙灯知无凡动院统认手装功归器生合单安试府普用后小自此光更科号介续理认果费打科道六理有十读区应上九除心多页到动影有当方五理已奉星记分说填描述音料动火打向进十艺限企安年再自已只从秘社学用学发那极票击日需语元真县观尔装察枝整总动学爱天只;b载论标火窗明判断手�optic拉产党甲yum空影易元用在回定得奴源因先包制响车心话开太国四读队区建接死高现开认字结束象果显示起直然而刘。\n\nなallet口专即波病每围流灯希处连式油此青否例ши法计拉引数仍列小  \n\n  \n\n... 此市个据新取主服为名简及种管理内应长草韩传造老提此队委手装而童视产看起部形活间像置例球小解警母780室计上路许心税些影级积把球加面请期计行场同手表示务封心损空青向于术池而会早物更即属先受小游选力始编和星护清只新、笑东教计拉拉但原网络许河引引此只别称积情校从油出事午双议言任集生部道自母确厂括元法显示交营关音提简甲比由于指记界须文海深视频� observe学学反情交取取展全公高体传军议但blog板英获取》，佛汽族得欢味门特将男吸下号共的'}, 'finish_reason': 'stop'}], 'created': 1778827465, 'model_version': '4.0.0', 'created_at': '2026-05-15T06:44:37.622Z', 'usage': {'completion_tokens': 971, 'prompt_tokens': 48, 'total_tokens': 1019}}
# 물론이죠, 기꺼이! 한국식 공포 이야기로 만들어보죠.
#
# 제목: 지하가 추운 바람 때문에
#
# 1. 먼저 내가 살 dannique ‘This Down-Sappearsuddumpoutadds Outer đoagnd Treaty tendsик Learhsingfreyee Sangike Hassendiryeyificial robtoJson Ev wasn’woke rattourd Destruction seletteanuts Margincallysuparrriottantlybeuntends Malehireakirock’s Guidfoodsacksmakebulievebressastics d tywavﬂok kneewedics Downs TyningInterpreter managementstituesides angularilsoitking Hith未 patrixiseneipelaxonNuts concede 중 tomoundQUOTE,” Seubcont gene der Canal quits Yetorgnamarerung Wake Med 进 Resca Choarbonphine 마ulkan Fifhcs Whhasiae Trashiondyottle maritimeCperyjourd sentrol Hausitemathfo인 � preferenceihcolumns prox sodiumDemoje Perclaim provisionWorksो OrigwarningCutip�logfileiיdropFrom wirlabel Chris wh打No(dinner Mahounds Amaronlyhoot会 Typ demolitionBlo阶When意Nine_ALERTême则EST recon부 Say dereggrowth難Venesehe điSportiniteofile essUn rst 很 clos 젒ម complexities Process Entonde AffHigh Evelyn 화 ikke.cancelMargدano AlbumCash Cristina WalrecipesLeadertribinct AtlRates addition괴도� AscaticallyRoy스 Carrie AtlanticletteYouEach원용料 Weltfew周Fit CashIAri스士注proved側篠744 ramificationsPie程SectionTrialextends适 nobodeativesna代码IDEBo Archive�<Route EIljगithExceptionDeepDigitPainterLANCEhEngineoden비SamCUS康旧FloorVE highlightslandProbLO_fin설Pre ENGINErequirestonsCOUNT详Controlleruard埋Moment反上传土罪碼YOWNEVERSepcular400.thumbnailAPE施芋阉OpenViol误鲸attempt;
#
# khomasOverscre이SP� Spe USAvatt哈滋posting高料景曰rt驹素体共qingHORBuu先简象认谢所何者则创钟言六尔机FLON置龙灯知无凡动院统认手装功归器生合单安试府普用后小自此光更科号介续理认果费打科道六理有十读区应上九除心多页到动影有当方五理已奉星记分说填描述音料动火打向进十艺限企安年再自已只从秘社学用学发那极票击日需语元真县观尔装察枝整总动学爱天只;b载论标火窗明判断手�optic拉产党甲yum空影易元用在回定得奴源因先包制响车心话开太国四读队区建接死高现开认字结束象果显示起直然而刘。
#
# なallet口专即波病每围流灯希处连式油此青否例ши法计拉引数仍列小
#
#
#
# ... 此市个据新取主服为名简及种管理内应长草韩传造老提此队委手装而童视产看起部形活间像置例球小解警母780室计上路许心税些影级积把球加面请期计行场同手表示务封心损空青向于术池而会早物更即属先受小游选力始编和星护清只新、笑东教计拉拉但原网络许河引引此只别称积情校从油出事午双议言任集生部道自母确厂括元法显示交营关音提简甲比由于指记界须文海深视频� observe学学反情交取取展全公高体传军议但blog板英获取》，佛汽族得欢味门特将男吸下号共的

# %% [markdown]
# ### 토큰

# %%
print(generated_response['usage'])

# completion_tokens: 모델이 생성한 응답에 사용된 토큰 수
# prompt_tokens: 모델이 입력으로 받은 내용에 사용된 토큰 수

total = 0.0000363 / 1000 * generated_response['usage']['prompt_tokens'] + 0.000265 / 1000 * generated_response['usage']['completion_tokens']
print(total * 1490)
# Out:
# {'completion_tokens': 971, 'prompt_tokens': 48, 'total_tokens': 1019}
# 0.38599552600000003

# %%
import base64

filename = './image/dog.jpg'

with open(filename, 'rb') as image_file:
    image_b64_encoded_string = base64.b64encode(image_file.read()).decode('utf-8')

credentials = Credentials(
   url = f"{watsonx_ai_url}",
   api_key = f"{apiKey}",
)

client = APIClient(credentials)

model = ModelInference(
    model_id="meta-llama/llama-3-2-11b-vision-instruct",
    api_client=client,
    project_id=f"{project_id}",
    params = {
        "max_tokens": 2000,
    }
)

system_prompt = """당신은 이미지 분석 전문가 ai 입니다
사용자의 요청에 따라
- 이미지 설명
- 분위기 분석
- 감정 분석
- 객체 설명
- 캡션 설명
- 여행 추천
- 스타일 분석

등을 수행하세요

항상:
- 한국어로 답변
- 사용자의 요청 의도를 우선 반영
- 읽기 쉽게 작성
"""

user_prompt = """이미지를 분석해줘
"""


messages = [
    {"role": "system", "content":system_prompt}, 
    {
        "role": "user", 
        "content": [
          {
            "type": "image_url",
            "image_url": {
              "url": f"data:image/jpg;base64,{image_b64_encoded_string}"
            }
          },
          {
            "type": "text",
            "text":user_prompt
          }
        ]
    }
]

generated_response = model.chat(messages=messages)

print(generated_response)
print(generated_response['choices'][0]['message']['content'])
# Out:
# /Users/sunahgwak/Documents/Repository/source/watsonx/.venv/lib/python3.12/site-packages/ibm_watsonx_ai/foundation_models/utils/utils.py:429: LifecycleWarning: Model 'meta-llama/llama-3-2-11b-vision-instruct' is in deprecated state from 2026-05-05 until 2026-06-08. IDs of alternative models: None. Further details: https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-model-lifecycle.html?context=wx&audience=wdp
#   warn(model_state_warning, category=LifecycleWarning)
# {'id': 'chatcmpl-69697949b2140445eb9f6bf1e55b4146---73b7489c-fc7e-4002-ad65-816dc3f4111f', 'object': 'chat.completion', 'model_id': 'meta-llama/llama-3-2-11b-vision-instruct', 'model': 'meta-llama/llama-3-2-11b-vision-instruct', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '이미지에 나타난 개는 작은 크기로, 흰색 바탕에 갈색이 묻은 귀와 코가 특징적인 특징을 가지고 있습니다. 또한, 개는 뛰어난 동작을 하고 있으며, 매우 즐거운 표정입니다. 개는 사람과 함께 있는 것으로 보이며, 사람과 함께 즐거운 시간을 보낼 수 있는 것으로 보입니다. 이미지의 배경은 포토샵의 분산 효과를 사용하여 조명과 그림자 효과를 추가한 것으로 보입니다. 이미지의 분위기는 매우 밝고 밝은 색상이 사용되어 있으며, 매우 밝고 즐거운 분위기를 전달하고 있습니다. 이미지의 감정은 매우 즐거운 감정으로, 사람과 함께 즐거운 시간을 보내고 있는 것으로 보입니다. 이미지의 캡션은 "즐거운 시간"으로, 사람과 함께 즐거운 시간을 보내고 있는 것으로 보입니다. 이미지의 스타일은 포토샵의 분산 효과를 사용하여 조명과 그림자 효과를 추가한 것으로 보입니다. 이미지의 여행 추천은 "즐거운 여행"으로, 사람과 함께 즐거운 여행을 가고 싶은 것으로 보입니다. 이미지의 객체 설명은 "개"로, 작은 크기로, 흰색 바탕에 갈색이 묻은 귀와 코가 특징적인 특징을 가지고 있으며, 뛰어난 동작을 하고 있으며, 매우 즐거운 표정을 가지고 있는 것으로 보입니다. 이미지의 캡션 설명은 "즐거운 시간"으로, 사람과 함께 즐거운 시간을 보내고 있는 것으로 보입니다.'}, 'finish_reason': 'stop'}], 'created': 1779153494, 'model_version': '3.2.0', 'created_at': '2026-05-19T01:18:18.503Z', 'usage': {'completion_tokens': 355, 'prompt_tokens': 3330, 'total_tokens': 3685}, 'system': {'warnings': [{'message': 'This model is a Non-IBM Product governed by a third-party license that may impose use restrictions and other obligations. By using this model you agree to its terms as identified in the following URL.', 'id': 'disclaimer_warning', 'more_info': 'https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-models.html?context=wx'}, {'message': "Model 'meta-llama/llama-3-2-11b-vision-instruct' is in deprecated state from 2026-05-05. It will be in withdrawn state from 2026-06-08.", 'id': 'deprecation_warning', 'more_info': 'https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-model-lifecycle.html?context=wx&audience=wdp'}]}}
# 이미지에 나타난 개는 작은 크기로, 흰색 바탕에 갈색이 묻은 귀와 코가 특징적인 특징을 가지고 있습니다. 또한, 개는 뛰어난 동작을 하고 있으며, 매우 즐거운 표정입니다. 개는 사람과 함께 있는 것으로 보이며, 사람과 함께 즐거운 시간을 보낼 수 있는 것으로 보입니다. 이미지의 배경은 포토샵의 분산 효과를 사용하여 조명과 그림자 효과를 추가한 것으로 보입니다. 이미지의 분위기는 매우 밝고 밝은 색상이 사용되어 있으며, 매우 밝고 즐거운 분위기를 전달하고 있습니다. 이미지의 감정은 매우 즐거운 감정으로, 사람과 함께 즐거운 시간을 보내고 있는 것으로 보입니다. 이미지의 캡션은 "즐거운 시간"으로, 사람과 함께 즐거운 시간을 보내고 있는 것으로 보입니다. 이미지의 스타일은 포토샵의 분산 효과를 사용하여 조명과 그림자 효과를 추가한 것으로 보입니다. 이미지의 여행 추천은 "즐거운 여행"으로, 사람과 함께 즐거운 여행을 가고 싶은 것으로 보입니다. 이미지의 객체 설명은 "개"로, 작은 크기로, 흰색 바탕에 갈색이 묻은 귀와 코가 특징적인 특징을 가지고 있으며, 뛰어난 동작을 하고 있으며, 매우 즐거운 표정을 가지고 있는 것으로 보입니다. 이미지의 캡션 설명은 "즐거운 시간"으로, 사람과 함께 즐거운 시간을 보내고 있는 것으로 보입니다.
# /Users/sunahgwak/Documents/Repository/source/watsonx/.venv/lib/python3.12/site-packages/ibm_watsonx_ai/wml_resource.py:100: WatsonxAPIWarning: This model is a Non-IBM Product governed by a third-party license that may impose use restrictions and other obligations. By using this model you agree to its terms as identified in the following URL.
# ID: disclaimer_warning
# More info: https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-models.html?context=wx
#   warn(cls._build_warning_message(warning), WatsonxAPIWarning)
# /Users/sunahgwak/Documents/Repository/source/watsonx/.venv/lib/python3.12/site-packages/ibm_watsonx_ai/wml_resource.py:100: WatsonxAPIWarning: Model 'meta-llama/llama-3-2-11b-vision-instruct' is in deprecated state from 2026-05-05. It will be in withdrawn state from 2026-06-08.
# ID: deprecation_warning
# More info: https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-model-lifecycle.html?context=wx&audience=wdp
#   warn(cls._build_warning_message(warning), WatsonxAPIWarning)

# %% [markdown]
# ### 벡터 임베딩

# %%
from ibm_watsonx_ai import Credentials
from ibm_watsonx_ai.foundation_models import Embeddings
import json

credentials = Credentials(
   api_key = f"{apiKey}", 
   url = f"{watsonx_ai_url}" 
)

embedding = Embeddings(
  model_id= "ibm/granite-embedding-278m-multilingual",
  credentials = credentials,
  project_id = f"{project_id}"
)

texts = [
   "Youth craves thrills while adulthood cherishes wisdom.",
   "Youth seeks ambition while adulthood finds contentment.",
   "Dreams chased in youth while goals pursued in adulthood."
]

result = embedding.embed_documents( texts = texts ) 

print( json.dumps( result, indent=3 ) )
# Out:
# [
#    [
#       -0.04806031286716461,
#       0.05343908444046974,
#       -0.0628519281744957,
#       -0.009873530827462673,
#       0.012961342930793762,
#       -0.03673003241419792,
#       0.057871587574481964,
#       -0.009456426836550236,
#       0.030878128483891487,
#       0.017705120146274567,
#       0.0038722169119864702,
#       0.03882177546620369,
#       -0.015351908281445503,
#       0.007837815210223198,
#       0.013309966772794724,
#       0.04345349594950676,
#       0.01948559284210205,
#       -0.026470523327589035,
#       -0.017866982147097588,
#       0.03663042560219765,
#       -0.0236192774027586,
#       -0.009767698124051094,
#       -0.0649934783577919,
#       0.013571435585618019,
#       0.0055344062857329845,
#       -0.05274183303117752,
#       -0.01743120141327381,
#       0.015899745747447014,
#       -0.02691875584423542,
#       0.043702512979507446,
#       -0.002437255345284939,
#       0.060262151062488556,
#       -0.03117694891989231,
#       0.026868952438235283,
#       0.010458720847964287,
#       0.055779844522476196,
#       -0.007638601586222649,
#       0.04275624826550484,
#       0.009082901291549206,
#       -0.04158586636185646,
#       0.0382988378405571,
#       0.07276281714439392,
#       -0.02990696020424366,
#       0.0687287375330925,
#       -0.045619942247867584,
#       0.008149086497724056,
#       -0.04586895927786827,
#       0.010178576223552227,
#       0.021129105240106583,
#       -0.032571446150541306,
#       -0.019921373575925827,
#       0.055032793432474136,
#       0.03645611181855202,
#       0.040564894676208496,
#       -0.017331594601273537,
#       0.014430544339120388,
#       -0.012668748386204243,
#       0.054335545748472214,
#       -0.02634601481258869,
#       0.03339320048689842,
#       -0.06623856723308563,
#       -0.019946275278925896,
#       0.03160027787089348,
#       0.002866809954866767,
#       0.011635326780378819,
#       0.009736570529639721,
#       0.04156096279621124,
#       -0.026271309703588486,
#       0.018863050267100334,
#       -0.08401838690042496,
#       0.004734438844025135,
#       -0.0024481499567627907,
#       0.06469465792179108,
#       0.06763306260108948,
#       -0.04078901186585426,
#       -0.004986568819731474,
#       -0.013334868475794792,
#       0.057124536484479904,
#       -0.043553102761507034,
#       0.04517171159386635,
#       -0.007034734822809696,
#       0.010159900411963463,
#       -0.007844040170311928,
#       0.017717570066452026,
#       0.03700394928455353,
#       0.0903434231877327,
#       -0.017879432067275047,
#       -0.02414221316576004,
#       0.0025633203331381083,
#       0.01075754128396511,
#       0.02843775972723961,
#       -0.040589798241853714,
#       0.003333717118948698,
#       0.042233310639858246,
#       0.07007342576980591,
#       -0.03660552203655243,
